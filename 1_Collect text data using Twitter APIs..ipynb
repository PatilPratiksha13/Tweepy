# %% [markdown]
# Collect text data using Twitter APIs.
# --------------------------------------------------
#
# There are a lot of free APIs through which we can collect data and use it to solve problems. We will learn the Twitter API in particular (as it can be used in many applications of NLP like product reviews, sentiment analysis,....).

# %% [markdown]
# Problem
# ------------
# You want to collect text data using Twitter APIs.
#
# Solution
# ------------
# Twitter has a gigantic amount of data with a lot of value in it. Social media
# marketers are making their living from it. There is an enormous amount
# of tweets every day, and every tweet has some story to tell. When all of this
# data is collected and analyzed, it gives a tremendous amount of insights to
# a business about their company, product, service, etc.
#
# How It Works
# -------------------
# Log in to the Twitter developer portal (https://developer.twitter.com/)
#
# Create your own app in the Twitter developer portal, and get the keys
# mentioned below. Once you have these credentials, you can start pulling
# data. Keys needed are:
#
# > • consumer key: Key associated with the application (Twitter, Facebook, etc.).
#
# > • consumer secret: Password used to authenticate with the authentication server
# (Twitter, Facebook, etc.).
#
# > • access token: Key given to the client after successful authentication of  above keys.
#
# > • access token secret: Password for the access key.

# %% [markdown]
# Useful links :
# -----------------
# https://iag.me/socialmedia/how-to-create-a-twitter-app-in-8-easy-steps/
#
# https://developer.twitter.com/en/docs/tweets/sample-realtime/overview/GET_statuse_sample

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (3.8.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (from tweepy) (1.7.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (from tweepy) (1.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (from requests>=2.11.1->tweepy) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (from requests>=2.11.1->tweepy) (1.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dell\appdata\local\programs\python\python36\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)

# %%
# Once all the credentials are in place, use the code below to fetch the data.

# Install tweepy
# !pip install tweepy

# Import the libraries
import numpy as np
import tweepy
import json
import pandas as pd
from tweepy import OAuthHandler

# credentials  --> put your credentials here
consumer_key = "yntx8srYI7fmIMdqnjUiKNtSQ"
consumer_secret = "fGRKUwI8JviZSipw2tCckuOMoBQXbrv9QaJjGOzTQZk8gLdKYj"
access_token = "782828160182136832-1ok7nP3EU273wTc8UMplSQzxnFvPJaA"
access_token_secret = "8v3bMePhsnuce9DDH5Ay0XImxu2mAXJkK8EPi3jgzfXGe"

# calling API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Provide the query you want to pull the data. For example,
# pulling data for "bollywood stars"
query = "republic day"

# Fetching tweets
Tweets = api.search(query, count = 10, lang='en', exclude='retweets',tweet_mode='extended')

for tweet in Tweets:
        print(tweet)
        print("----------------------")

# The query above will pull the top 10 tweets when the term "JP Morgan" 
# is searched. The API will pull English tweets since the language 
# given is ‘en’ and it will exclude retweets.
# Out:
# Status(_api=<tweepy.api.API object at 0x0000000A038EC390>, _json={'created_at': 'Sun Jan 26 05:47:26 +0000 2020', 'id': 1221308643506708480, 'id_str': '1221308643506708480', 'full_text': '@SakshiMalik Happy republic day', 'truncated': False, 'display_text_range': [13, 31], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SakshiMalik', 'name': 'Sakshi Malik', 'id': 728173090027520000, 'id_str': '728173090027520000', 'indices': [0, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1221303407538917376, 'in_reply_to_status_id_str': '1221303407538917376', 'in_reply_to_user_id': 728173090027520000, 'in_reply_to_user_id_str': '728173090027520000', 'in_reply_to_screen_name': 'SakshiMalik', 'user': {'id': 1147806560288043009, 'id_str': '1147806560288043009', 'name': '_sujit_RISER', 'screen_name': 'RiserSujit', 'location': '', 'description': 'live like king size', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 5, 'friends_count': 72, 'listed_count': 0, 'created_at': 'Sun Jul 07 09:56:23 +0000 2019', 'favourites_count': 522, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 7, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/
com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 308, 'friends_count': 1797, 'listed_count': 1, 'created_at': 'Tue Dec 18 04:33:12 +0000 2018', 'favourites_count': 47, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 46, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1105431850858762240/Z8bCn4bJ_ ...
# ----------------------
# Status(_api=<tweepy.api.API object at 0x0000000A038EC390>, _json={'created_at': 'Sun Jan 26 05:47:24 +0000 2020', 'id': 1221308637651431424, 'id_str': '1221308637651431424', 'full_text': '🇮🇳 Happy Republic Day 🇮🇳 \n#जयहिंद', 'truncated': False, 'display_text_range': [0, 33], 'entities': {'hashtags': [{'text': 'जयहिंद', 'indices': [26, 33]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 105750737, 'id_str': '105750737', 'name': 'सिद्धांत | سدھانت', 'screen_name': 'Siddhant01', 'location': 'INDIA', 'description': 'Author of #Simplysiddh \nInstagram - @simplysiddh', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 5280, 'friends_count': 223, 'listed_count': 36, 'created_at': 'Sun Jan 17 10:29:59 +0000 2010', 'favourites_count': 28527, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 32259, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFF04D', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1219237633190031360/Y1A1uEyn_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1219237633190031360/Y1A1uEyn_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/105750737/1451620419', 'profile_link_color': 'DD2E44', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 1, 26, 5, 47, 24), id=1221308637651431424, id_str='1221308637651431424', full_text='🇮🇳 Happy Republic Day 🇮🇳 \n#जयहिंद', truncated=False, display_text_range=[0, 33], entities={'hashtags': [{'text': 'जयहिंद', 'indices': [26, 33]}], 'symbols': [], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000000A038EC390>, _json={'id': 105750737, 'id_str': '105750737', 'name': 'सिद्धांत | سدھانت', 'screen_name': 'Siddhant01', 'location': 'INDIA', 'description': 'Author of #Simplysiddh \nInstagram - @simplysiddh', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 5280, 'friends_count': 223, 'listed_count': 36, 'created_at': 'Sun Jan 17 10:29:59 +0000 2010', 'favourites_count': 28527, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 32259, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFF04D', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_tile': False, 'profile_image_url ...
# ----------------------
# Status(_api=<tweepy.api.API object at 0x0000000A038EC390>, _json={'created_at': 'Sun Jan 26 05:47:23 +0000 2020', 'id': 1221308634644336641, 'id_str': '1221308634644336641', 'full_text': '@D_Roopa_IPS Happy Republic Day to you also🙏🇮🇳', 'truncated': False, 'display_text_range': [13, 46], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'D_Roopa_IPS', 'name': 'D Roopa IPS', 'id': 734751240047853568, 'id_str': '734751240047853568', 'indices': [0, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1221304966633017344, 'in_reply_to_status_id_str': '1221304966633017344', 'in_reply_to_user_id': 734751240047853568, 'in_reply_to_user_id_str': '734751240047853568', 'in_reply_to_screen_name': 'D_Roopa_IPS', 'user': {'id': 138292756, 'id_str': '138292756', 'name': 'Mr. Shairon', 'screen_name': 'shairon_indic', 'location': 'London, England', 'description': 'Learner, Seeker,  No Prejudice,  Running and Fitness...Views are strictly personal. RTs are not endorsements.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 126, 'friends_count': 905, 'listed_count': 0, 'created_at': 'Thu Apr 29 04:13:57 +0000 2010', 'favourites_count': 16991, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8474, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1194980477372895234/47abFgVg_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1194980477372895234/47abFgVg_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 1, 26, 5, 47, 23), id=1221308634644336641, id_str='1221308634644336641', full_text='@D_Roopa_IPS Happy Republic Day to you also🙏🇮🇳', truncated=False, display_text_range=[13, 46], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'D_Roopa_IPS', 'name': 'D Roopa IPS', 'id': 734751240047853568, 'id_str': '734751240047853568', 'indices': [0, 12]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1221304966633017344, in_reply_to_status_id_str='1221304966633017344', in_reply_to_user_id=734751240047853568, in_reply_to_user_id_str='734751240047853568', in_reply_to_screen_name='D_Roopa_IPS', author=User(_api=<tweepy.api.API object at 0x0000000A038EC390>, _json={'id': 138292756, 'id_str': '138292756', 'name': 'Mr. Shairon', 'screen_name': 'shairon_indic', 'location': 'London, England', 'description': 'Learner, Seeker,  No Prejudice,  Running and Fitness...Views are strictly personal. RTs are not endorsements.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 126, 'friends_count': 905, 'listed_count': 0, 'created_at': 'Thu Apr 29 04:13:57 +0000 2010', 'favourites_count': 16991, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, ...
# ----------------------
# Status(_api=<tweepy.api.API object at 0x0000000A038EC390>, _json={'created_at': 'Sun Jan 26 05:47:23 +0000 2020', 'id': 1221308633654280192, 'id_str': '1221308633654280192', 'full_text': 'A republic day gift to all from @P4LOIndia. Our techno legal startups @_TeleLaws and @ODRIndia would help Indian and global stakeholders to meet their compliance requirements in India at concessional rates as part of our CSR. In deserving cases it can be free too. #DigitalIndia https://t.co/ywc2l5TqBF', 'truncated': False, 'display_text_range': [0, 278], 'entities': {'hashtags': [{'text': 'DigitalIndia', 'indices': [265, 278]}], 'symbols': [], 'user_mentions': [{'screen_name': 'P4LOIndia', 'name': 'P4LO', 'id': 4089296952, 'id_str': '4089296952', 'indices': [32, 42]}, {'screen_name': '_TeleLaws', 'name': 'TeleLaw- A Legal Tech, Reg Tech & Tech Law Startup', 'id': 1137574364046487557, 'id_str': '1137574364046487557', 'indices': [70, 80]}, {'screen_name': 'odrindia', 'name': 'ODR India', 'id': 2971490916, 'id_str': '2971490916', 'indices': [85, 94]}], 'urls': [], 'media': [{'id': 1221308623713759232, 'id_str': '1221308623713759232', 'indices': [279, 302], 'media_url': 'http://pbs.twimg.com/media/EPL1uPWUcAAUpqf.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EPL1uPWUcAAUpqf.jpg', 'url': 'https://t.co/ywc2l5TqBF', 'display_url': 'pic.twitter.com/ywc2l5TqBF', 'expanded_url': 'https://twitter.com/_PTLB/status/1221308633654280192/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 500, 'h': 300, 'resize': 'fit'}, 'large': {'w': 500, 'h': 300, 'resize': 'fit'}, 'small': {'w': 500, 'h': 300, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1221308623713759232, 'id_str': '1221308623713759232', 'indices': [279, 302], 'media_url': 'http://pbs.twimg.com/media/EPL1uPWUcAAUpqf.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EPL1uPWUcAAUpqf.jpg', 'url': 'https://t.co/ywc2l5TqBF', 'display_url': 'pic.twitter.com/ywc2l5TqBF', 'expanded_url': 'https://twitter.com/_PTLB/status/1221308633654280192/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 500, 'h': 300, 'resize': 'fit'}, 'large': {'w': 500, 'h': 300, 'resize': 'fit'}, 'small': {'w': 500, 'h': 300, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 888808440583172096, 'id_str': '888808440583172096', 'name': 'PTLB', 'screen_name': '_PTLB', 'location': '', 'description': '@PTLB Is The Premier #TechnoLegal #LegalTech Segment Of @P4LOIndia. #PTLB Is Managing Many #OnlineEducation, #Training And #EduTech/#EdTech Projects Of P4LO.', 'url': 'https://t.co/chrw3UlSiS', 'entities': {'url': {'urls': [{'url': 'https://t.co/chrw3UlSiS', 'expanded_url': 'http://www.ptlb.in/', 'display_url': 'ptlb.in', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 91, 'friends_count': 5, 'listed_count': 8, 'created_at': 'Sat Jul 22 17:10:20 +0000 2017', 'favourites_count': 9828, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 17958, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/888814837236604928/zmPFhjim_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/888814837236604928/zmPFhjim_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/888808440583172096/1500744880', 'profile_link_color': '1DA1F2', 'profile_sidebar_bo ...
# ----------------------
# Status(_api=<tweepy.api.API object at 0x0000000A038EC390>, _json={'created_at': 'Sun Jan 26 05:47:23 +0000 2020', 'id': 1221308633280958464, 'id_str': '1221308633280958464', 'full_text': 'On this special day let’s pledge to do our little bit everyday to better our nation in every possible way. Proud to be an Indian . Jaihind !! Happy Republic Day🇮🇳 #JaiHind #RepublicDay2020 https://t.co/D1K307lTJP', 'truncated': False, 'display_text_range': [0, 188], 'entities': {'hashtags': [{'text': 'JaiHind', 'indices': [163, 171]}, {'text': 'RepublicDay2020', 'indices': [172, 188]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1221308619292991489, 'id_str': '1221308619292991489', 'indices': [189, 212], 'media_url': 'http://pbs.twimg.com/media/EPL1t-4U4AExgiW.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EPL1t-4U4AExgiW.jpg', 'url': 'https://t.co/D1K307lTJP', 'display_url': 'pic.twitter.com/D1K307lTJP', 'expanded_url': 'https://twitter.com/neev_bapodra/status/1221308633280958464/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 750, 'h': 1125, 'resize': 'fit'}, 'small': {'w': 453, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 1125, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1221308619292991489, 'id_str': '1221308619292991489', 'indices': [189, 212], 'media_url': 'http://pbs.twimg.com/media/EPL1t-4U4AExgiW.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EPL1t-4U4AExgiW.jpg', 'url': 'https://t.co/D1K307lTJP', 'display_url': 'pic.twitter.com/D1K307lTJP', 'expanded_url': 'https://twitter.com/neev_bapodra/status/1221308633280958464/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 750, 'h': 1125, 'resize': 'fit'}, 'small': {'w': 453, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 1125, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3181888980, 'id_str': '3181888980', 'name': 'Neev Bapodra', 'screen_name': 'neev_bapodra', 'location': 'Junagadh, Gujrat, India.', 'description': 'Vloger, YouTuber, Traveller,\nMoody, ❤Romantic, Fire N DESIRE!!!!!', 'url': 'https://t.co/WkTJF3q6fr', 'entities': {'url': {'urls': [{'url': 'https://t.co/WkTJF3q6fr', 'expanded_url': 'https://www.youtube.com/channel/UCUMU0zCV3Pcv0SfVKaitsYA', 'display_url': 'youtube.com/channel/UCUMU0…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 89, 'friends_count': 370, 'listed_count': 0, 'created_at': 'Fri May 01 16:21:49 +0000 2015', 'favourites_count': 1095, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 450, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1210617971564929024/V8fk4TmJ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1210617971564929024/V8fk4TmJ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3181888980/1558862916', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': N ...
# ----------------------

# %% [markdown]
# Getting the Tweets + Some Attributes
# ------------------------------------
# In this section, we will get some tweets plus some of their related attributes and store them in a structured format.
#
# If we are interested in getting more than 100 tweets at a time, which we are in our case, we will not be able to do so by just using api.search. We will need to use tweepy.Cursor which will allow us to get as many tweets as we desire. I did not get too deep into trying to understand what Cursoring does, but the general idea in our case is that it will allow us to read 100 tweets, store them in a page inherently, then read the next 100 tweets.
#
# For our purpose, the end result is that it will just keep going on fetching tweets until we ask it to stop by breaking the loop.

# %%
# start by creating an empty DataFrame with the columns we'll need
df = pd.DataFrame(columns = ['Tweets', 'User', 'User_statuses_count', 
                             'user_followers', 'User_location', 'User_verified',
                             'fav_count', 'rt_count', 'tweet_date'])

# %%
# Next, lets define a function as follows.
def stream(data, file_name):
    i = 0
    for tweet in tweepy.Cursor(api.search, q=data, count=100, lang='en').items():
        print(i, end='\r') # '\r' is like home button, this will bring the cursor back on home position. if you do not give this python wlil take the cursor on next line after print
        df.loc[i, 'Tweets'] = tweet.text
        df.loc[i, 'User'] = tweet.user.name
        df.loc[i, 'User_statuses_count'] = tweet.user.statuses_count  # indicates the no. of times the user as tweeted 
        df.loc[i, 'user_followers'] = tweet.user.followers_count
        df.loc[i, 'User_location'] = tweet.user.location
        df.loc[i, 'User_verified'] = tweet.user.verified
        df.loc[i, 'fav_count'] = tweet.favorite_count # indicates number of tweets the user has marked as fav
        df.loc[i, 'rt_count'] = tweet.retweet_count
        df.loc[i, 'tweet_date'] = tweet.created_at
        df.to_excel('{}.xlsx'.format(file_name))
        i+=1
        if i == 1000:
            break
        else:
            pass

# %% [markdown]
# Let's look at this function from the inside out:
# ------------------------------------------------
# >First, we followed the same methodology of getting each tweet in a for loop, but this time from tweepy.Cursor.
#
# >Inside tweepy.Cursor, we pass our api.search and the attributes we want: q = data: data will be whatever piece of text we pass into the stream function to ask our api.search to search for just like we did passing "JP Morgan India" in the previous example.
#
# count = 100: Here we are setting the number of tweets to return to 100, via api.search, which is the maximum possible number.
#
# lang = 'en': Here I am simply filtering results to return tweets in English only.
#
# Next, I am filling my DataFrame with the attributes I am interested in and during each iteration making use of the .loc method in Pandas and my i counter.
#
# The attributes I am passing into each column are self explanatory and you can look into the Twitter API documentation for what other attributes are available and play around with those.
#
# >Finally I am saving the result into an excel file using "df.to_excel" and here I am using a placeholder {} instead of naming the file inside the function because I want to be able to name the file myself when I run the function.
#
# Now, I can just call my function as follows, looking for tweets about food again and naming my file "my_tweets."
#
# Now, since we put our api.search into tweepy.Cursor, it will not just stop at the first 100 tweets. It will instead keep going on forever; that's why we are using i as a counter to stop the loop after 1000 iterations.

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading https://files.pythonhosted.org/packages/6f/af/88ff9eef0b8f665aee1111ac6cede5ad12190c5bd726242bd2b26fc21b32/openpyxl-3.0.0.tar.gz (172kB)
# Collecting jdcal
#   Using cached https://files.pythonhosted.org/packages/f0/da/572cbc0bc582390480bbd7c4e93d14dc46079778ed915b505dc494b37c57/jdcal-1.4.1-py2.py3-none-any.whl
# Collecting et_xmlfile
#   Using cached https://files.pythonhosted.org/packages/22/28/a99c42aea746e18382ad9fb36f64c1c1f04216f41797f2f0fa567da11388/et_xmlfile-1.0.1.tar.gz
# Installing collected packages: jdcal, et-xmlfile, openpyxl
#     Running setup.py install for et-xmlfile: started
#     Running setup.py install for et-xmlfile: finished with status 'done'
#     Running setup.py install for openpyxl: started
#     Running setup.py install for openpyxl: finished with status 'done'
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4.1 openpyxl-3.0.0

# %%
# calling the above function 
stream(data = ['JP Morgan India'], file_name = 'my_tweets')
# Out:
# 113

# %%
# view first 5 records
df.head()
# Out:
#                                               Tweets  \
# 0  RT @narendramodi: Very good interaction with t...
# 1  RT @narendramodi: Very good interaction with t...
# 2  Omg guys there is a whole protest tmrw over CE...
# 3  RT @narendramodi: Very good interaction with t...
# 4  'The JP Morgan International Council which was...
#
#                            User User_statuses_count user_followers  \
# 0                             .               99130            761
# 1               Aman Srivastava               37255            211
# 2                        vishan                9941            341
# 3  BJP Mahila Morcha Chandrapur                 851            190
# 4             Dawn. A. Alderson               51151             15
#
#            User_location User_verified fav_count rt_count           tweet_date
# 0          Mumbai, India         False         0     2577  2019-11-03 03:00:04
# 1         Gyanpur, India         False         0     2577  2019-11-02 07:24:23
# 2                                False         5        0  2019-11-02 05:46:30
# 3                                False         0     2577  2019-11-02 03:23:45
# 4  Wales, United Kingdom         False         0        0  2019-11-01 21:58:04

# %% [markdown]
# Let's Analyze Some Tweets
# --------------------------

# %%
# !pip install TextBlob
# Out:
# Collecting TextBlob
#   Downloading https://files.pythonhosted.org/packages/60/f0/1d9bfcc8ee6b83472ec571406bd0dd51c0e6330ff1a51b2d29861d389e85/textblob-0.15.3-py2.py3-none-any.whl (636kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages (from TextBlob) (3.4.5)
# Requirement already satisfied: six in c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages (from nltk>=3.1->TextBlob) (1.12.0)
# Installing collected packages: TextBlob
# Successfully installed TextBlob-0.15.3

# %%
# importing TextBlob. It has build-in sentiment property
from textblob import TextBlob

# The sentiment property returns a named tuple of the form 
# Sentiment(polarity,subjectivity). The polarity score is a float 
# within the range [-1.0, 1.0]. 
# The subjectivity is a float within the range [0.0, 1.0] 
# where 0.0 is very objective and 1.0 is very subjective.

# %% [markdown]
# >I would like to add an extra column to this DataFrame that indicates the sentiment of a tweet.
#
# >We will also need to add another column with the tweets stripped of useless symbols, then run the sentiment analyzer on those cleaned up tweets to be more effective.

# %%
# Let's start by writing our tweets cleaning function:
import re
def clean_tweet(tweet):
    return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', tweet).split())

# small w means any word, capital W means any non word
# small s means space and capital S means non-space
# split is used coz all the banlks which are converted above will be cleaned as only data will be split

# %%
# Let's also write our sentiment analyzer function:
def analyze_sentiment(tweet):
    analysis = TextBlob(tweet)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity ==0:
        return 'Neutral'
    else:
        return 'Negative'

# %%
# Now let's create our new columns:
df['clean_tweet'] = df['Tweets'].apply(lambda x: clean_tweet(x))
df['Sentiment'] = df['clean_tweet'].apply(lambda x: analyze_sentiment(x))

# %%
# Let's look at some random rows to make sure our functions worked correctly.

# Example (100th row):
n=100
print('Original tweet:\n'+ df['Tweets'][n])
print()
print('Clean tweet:\n'+df['clean_tweet'][n])
print()
print('Sentiment:\n'+df['Sentiment'][n])
# Out:
# Original tweet:
# RT @narendramodi: Very good interaction with the JP Morgan International Council, an illustrious gathering of top policy makers, thinkers,…
#
# Clean tweet:
# RT Very good interaction with the JP Morgan International Council an illustrious gathering of top policy makers thinkers
#
# Sentiment:
# Positive

# %%
# Let's look at some random rows to make sure our functions worked correctly.

# Example (60th row):
n=25
print('Original tweet:\n'+ df['Tweets'][n])
print()
print('Clean tweet:\n'+df['clean_tweet'][n])
print()
print('Sentiment:\n'+df['Sentiment'][n])
# Out:
# Original tweet:
# After 12 years JP Morgan International Council meet held in India, PM Modi meets powerful leaders… https://t.co/F736oJRC2O
#
# Clean tweet:
# After 12 years JP Morgan International Council meet held in India PM Modi meets powerful leaders
#
# Sentiment:
# Positive
#                                                Tweets                 User  \
# 26  @dominos_india I have been trying to order piz...              Rajguru
# 44  India Has Unbelievable Skills But Needs to Tra...  Wadhwani Foundation
#
#    User_statuses_count user_followers User_location User_verified fav_count  \
# 26                 596             19                       False         0
# 44                8738           6480                       False         0
#
#    rt_count           tweet_date  \
# 26        0  2019-10-29 15:59:25
# 44        0  2019-10-28 06:58:53
#
#                                           clean_tweet Sentiment
# 26  india I have been trying to order pizza since ...  Negative
# 44  India Has Unbelievable Skills But Needs to Tra...  Negative

# %%
df[df.Sentiment == 'Negative'].shape[0]
# Out:
# 2

# %%
df[df.Sentiment == 'Positive'].shape[0]
# Out:
# 107

# %%
df[df.Sentiment == 'Neutral'].shape[0]
# Out:
# 5

# %%
# Once all the credentials are in place, use the code below to fetch the data.

# Install tweepy
# !pip install tweepy

# Import the libraries
import numpy as np
import tweepy
import json
import pandas as pd
from tweepy import OAuthHandler

# credentials  --> put your credentials here
consumer_key = "yntx8srYI7fmIMdqnjUiKNtSQ"
consumer_secret = "fGRKUwI8JviZSipw2tCckuOMoBQXbrv9QaJjGOzTQZk8gLdKYj"
access_token = "782828160182136832-1ok7nP3EU273wTc8UMplSQzxnFvPJaA"
access_token_secret = "8v3bMePhsnuce9DDH5Ay0XImxu2mAXJkK8EPi3jgzfXGe"

# calling API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Provide the query you want to pull the data. For example,
# pulling data for "bollywood stars"
query = "BJP Shiv Sena Alliance"

# Fetching tweets
Tweets = api.search(query, count = 10, lang='en', exclude='retweets',tweet_mode='extended')

for tweet in Tweets:
        print(tweet)
        print("----------------------")

# The query above will pull the top 10 tweets when the term "JP Morgan" 
# is searched. The API will pull English tweets since the language 
# given is ‘en’ and it will exclude retweets.
# Out:
# Status(_api=<tweepy.api.API object at 0x0000000012CFC5F8>, _json={'created_at': 'Sun Nov 03 05:04:33 +0000 2019', 'id': 1190857272647282689, 'id_str': '1190857272647282689', 'full_text': 'Fate Of Maharashtra Assembly Elections  BJP Alliance Shiv Sena  The Winner Astrologer Anil Aggarwala https://t.co/V2IE50Exny', 'truncated': False, 'display_text_range': [0, 124], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/V2IE50Exny', 'expanded_url': 'https://www.astrodocanil.com/2019/11/fate-of-maharashtra-assembly-elections-bjp-alliance-shiv-sena-the-winner-astrologer-anil-aggarwala/', 'display_url': 'astrodocanil.com/2019/11/fate-o…', 'indices': [101, 124]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 362615267, 'id_str': '362615267', 'name': 'Astrologer-astrodocanil-www.astrodocanil.com', 'screen_name': 'aggarwalaanil', 'location': 'New Delhi, India', 'description': '@astrodocanil', 'url': 'https://t.co/dvaqtyvgGg', 'entities': {'url': {'urls': [{'url': 'https://t.co/dvaqtyvgGg', 'expanded_url': 'http://www.astrodocanil.com', 'display_url': 'astrodocanil.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 194, 'friends_count': 7, 'listed_count': 4, 'created_at': 'Fri Aug 26 17:59:25 +0000 2011', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1832, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/997757464945741825/cvGBl6dr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/997757464945741825/cvGBl6dr_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/362615267/1526717122', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 11, 3, 5, 4, 33), id=1190857272647282689, id_str='1190857272647282689', full_text='Fate Of Maharashtra Assembly Elections  BJP Alliance Shiv Sena  The Winner Astrologer Anil Aggarwala https://t.co/V2IE50Exny', truncated=False, display_text_range=[0, 124], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co
}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1640179939, 'id_str': '1640179939', 'name': 'Panipat War', 'screen_name': 'Panipat_1761', 'location': 'Maharashtra, Hindusthan', 'description': 'Panipat is Punyapat .Follow 4 tweets on info related to #Hindu sacrifice for the country/religion in Panipat war.#Panipat3 A Maratha school of Thought.#Marathas', 'url': 'https://t.co/CqKR5T6uEq', 'entities': {'url': {'urls': [{'url': 'https://t.co/CqKR5T6uEq', 'expanded_url': 'http://www.hritambhara.com', 'display_url': 'hritambhara.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4092, 'friends_count': 27, 'listed_count': 31, 'created_at': 'Fri Aug 02 10:34:29 +0000 2013', 'favourites_count': 7751, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 12850, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1151866438111547392/gkALaVgw_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1151866438111547392/gkALaVgw_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1640179939/1510727935', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1190563942352818176, 'quoted_status_id_str': '1190563942352818176', 'quoted_status': {'created_at': 'Sat Nov 02 09:38:58 +0000 2019', 'id': 1190563942352818176, 'id_str': '1190563942352818176', 'full_text': "Hindus have always betrayed Hindus, from the time of Alexander the great's alliance with the king of Taxila against Porus to Shiv Sena today https://t.co/amwliVrjQH", 'truncated': False, 'display_text_range': [0, 140], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/amwliVrjQH', 'expanded_url': 'https://twitter.com/MinhazMerchant/status/1190540562589474817', 'display_url': 'twitter.com/MinhazMerchant…', 'indices': [141, 164]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': Non ...
# ----------------------
# Status(_api=<tweepy.api.API object at 0x0000000012CFC5F8>, _json={'created_at': 'Sun Nov 03 03:02:21 +0000 2019', 'id': 1190826519834157057, 'id_str': '1190826519834157057', 'full_text': '@TimesNow @rautsanjay61 Enough is enough. End alliance with Shiv Sena. If BJP is to have any truck with the Sena the first condition must be that this rogue and haramkhor called Sanjay Raut be expelled from the party. Let him join the NCP or the Congress.', 'truncated': False, 'display_text_range': [24, 255], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TimesNow', 'name': 'TIMES NOW', 'id': 240649814, 'id_str': '240649814', 'indices': [0, 9]}, {'screen_name': 'rautsanjay61', 'name': 'Sanjay Raut', 'id': 2243917723, 'id_str': '2243917723', 'indices': [10, 23]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1190705886743937024, 'in_reply_to_status_id_str': '1190705886743937024', 'in_reply_to_user_id': 240649814, 'in_reply_to_user_id_str': '240649814', 'in_reply_to_screen_name': 'TimesNow', 'user': {'id': 3759455113, 'id_str': '3759455113', 'name': 'Sandeep Nimbark', 'screen_name': 'nimbark_sandeep', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 10, 'friends_count': 22, 'listed_count': 0, 'created_at': 'Fri Oct 02 13:35:06 +0000 2015', 'favourites_count': 23, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4252, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 11, 3, 3, 2, 21), id=1190826519834157057, id_str='1190826519834157057', full_text='@TimesNow @rautsanjay61 Enough is enough. End alliance with Shiv Sena. If BJP is to have any truck with the Sena the first condition must be that this rogue and haramkhor called Sanjay Raut be expelled from the party. Let him join the NCP or the Congress.', truncated=False, display_text_range=[24, 255], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TimesNow', 'name': 'TIMES NOW', 'id': 240649814, 'id_str': '240649814', 'indices': [0, 9]}, {'screen_name': 'rautsanjay61', 'name': 'Sanjay Raut', 'id': 2243917723, 'id_str': '2243917723', 'indices': [10, 23]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1190705886743937024, in_reply_to_status_id_str='1190705886743937024', in_reply_to_user_id=240649814, in_reply_to_user_id_str='240649814', in_reply_to_screen_name='TimesNow', author=User(_api=<tweepy.api.API object at 0x0000000012CFC5F8>, _json={'id': 3759455113, 'id_str': '3759455113', 'name': 'Sandeep Nimbark', 'screen_name': 'nimbark_sandeep ...
# ----------------------
# Status(_api=<tweepy.api.API object at 0x0000000012CFC5F8>, _json={'created_at': 'Sun Nov 03 02:54:26 +0000 2019', 'id': 1190824528210886658, 'id_str': '1190824528210886658', 'full_text': '@PanditRamJoshi Breaking shiv sena would mean entirely breaking the alliance for once and forever  . It would be difficult in future to use shiv sena votes to make govts . Moreover congress/ncp/mns mlas go behind money whereas bjp &amp; S.S mlas already have loads of money  .', 'truncated': False, 'display_text_range': [16, 276], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PanditRamJoshi', 'name': 'Pandit Ram Joshi', 'id': 323995057, 'id_str': '323995057', 'indices': [0, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1190689554723819520, 'in_reply_to_status_id_str': '1190689554723819520', 'in_reply_to_user_id': 323995057, 'in_reply_to_user_id_str': '323995057', 'in_reply_to_screen_name': 'PanditRamJoshi', 'user': {'id': 760480194402652160, 'id_str': '760480194402652160', 'name': 'Hemish shah', 'screen_name': 'hmshah1212', 'location': '', 'description': 'GREATEST DEVOTEE OF LORD RAVANA, JAIN , YOUTUBER , NATIONALIST , SOCIAL MEDIA INFLUENCER , STUDENT', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 526, 'friends_count': 1943, 'listed_count': 2, 'created_at': 'Tue Aug 02 14:19:42 +0000 2016', 'favourites_count': 20958, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 53734, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1177586880285556736/muPIcYOj_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1177586880285556736/muPIcYOj_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/760480194402652160/1558197880', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 11, 3, 2, 54, 26), id=1190824528210886658, id_str='1190824528210886658', full_text='@PanditRamJoshi Breaking shiv sena would mean entirely breaking the alliance for once and forever  . It would be difficult in future to use shiv sena votes to make govts . Moreover congress/ncp/mns mlas go behind money whereas bjp &amp; S.S mlas already have loads of money  .', truncated=False, display_text_range=[16, 276], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PanditRamJoshi', 'name': 'Pandit Ram Joshi', 'id': 323995057, 'id_str': '323995057', 'indices': [0, 15]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1190689554723819520, in_reply_to_status_id_str='1190689554723819520', in_reply_to_user_id=323995057, in_reply_to_user_id_str='323995057', in_reply_to_screen_name='PanditRamJoshi', author=User(_api=<tweepy.api.API object at 0x0000000012CFC5F8>, _json={'id': 760480194402652160, 'id_str': '760480194402652160', 'name': 'Hemish shah', 'screen_name': 'hmshah1212', 'location': '', 'description': 'GREAT ...
# ----------------------
# Status(_api=<tweepy.api.API object at 0x0000000012CFC5F8>, _json={'created_at': 'Sun Nov 03 02:50:10 +0000 2019', 'id': 1190823454519386112, 'id_str': '1190823454519386112', 'full_text': '@madhusudan41 @rautsanjay61 @MumbaiMirror @INCIndia @BJP4India @PawarSpeaks @ahmedpatel Everyone fought separately then so no betrayal. Here Shiv sena fought in alliance and not even once mentioned about this stupid 50:50 before elections. So this is clear betrayal. \n\nAlso, BJP wants SS to align with Congress. Both will be finished. MIM already snatched muslim votes', 'truncated': False, 'display_text_range': [88, 368], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'madhusudan41', 'name': 'Madhusudan Thakkar', 'id': 163742316, 'id_str': '163742316', 'indices': [0, 13]}, {'screen_name': 'rautsanjay61', 'name': 'Sanjay Raut', 'id': 2243917723, 'id_str': '2243917723', 'indices': [14, 27]}, {'screen_name': 'MumbaiMirror', 'name': 'Mumbai Mirror', 'id': 990761677, 'id_str': '990761677', 'indices': [28, 41]}, {'screen_name': 'INCIndia', 'name': 'Congress', 'id': 1153045459, 'id_str': '1153045459', 'indices': [42, 51]},
_api=<tweepy.api.API object at 0x0000000012CFC5F8>, _json={'id': 1162997036091731968, 'id_str': '1162997036091731968', 'name': 'Padmichetty Krishnamoorthy Venkataramen Venkat', 'screen_name': 'venkataramen', 'location': '', 'descriptio ...
# ----------------------
# Status(_api=<tweepy.api.API object at 0x0000000012CFC5F8>, _json={'created_at': 'Sun Nov 03 00:15:00 +0000 2019', 'id': 1190784403611537408, 'id_str': '1190784403611537408', 'full_text': 'Not only has the tally of both the BJP and Shiv Sena came down, compared to the alliance’s performance in 2014 assembly elections, but even the vote share has come down in comparison to the 2019 Lok Sabha polls, points out Satish Misra: https://t.co/f3JOgosscX', 'truncated': False, 'display_text_range': [0, 260], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/f3JOgosscX', 'expanded_url': 'https://bit.ly/36eJZxw', 'display_url': 'bit.ly/36eJZxw', 'indices': [237, 260]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 180748385, 'id_str': '180748385', 'name': 'ORF', 'screen_name': 'orfonline', 'location': 'India', 'description': 'Non–partisan, independent analyses on security, strategy, economy, development, energy & global governance. Sign up for our newsletter: https://t.co/BG3eHPHhm6', 'url': 'https://t.co/jKaTttKtaw', 'entities': {'url': {'urls': [{'url': 'https://t.co/jKaTttKtaw', 'expanded_url': 'http://www.orfonline.org', 'display_url': 'orfonline.org', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/BG3eHPHhm6', 'expanded_url': 'http://goo.gl/I2kCjh', 'display_url': 'goo.gl/I2kCjh', 'indices': [136, 159]}]}}, 'protected': False, 'followers_count': 49960, 'friends_count': 151, 'listed_count': 676, 'created_at': 'Fri Aug 20 11:19:22 +0000 2010', 'favourites_count': 273, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 105229, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '4388F0', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/875617363089018880/418zc2ld_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875617363089018880/418zc2ld_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/180748385/1558692545', 'profile_link_color': '1B5AB8', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DAECF4', 'profile_text_color': '663B12', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 11, 3, 0, 15), id=1190784403611537408, id_str='1190784403611537408', full_text='Not only has the tally of both the BJP and Shiv Sena came down, compared to the alliance’s performance in 2014 assembly elections, but even the vote share has come down in comparison to the 2019 Lok Sabha polls, points out Satish Misra: https://t.co/f3JOgosscX', truncated=False, display_text_range=[0, 260], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/f3JOgosscX', 'expanded_url': 'https://bit.ly/36eJZxw', 'display_url': 'bit.ly/36eJZxw', 'indices': [237, 260]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='TweetDeck', source_url='https://about.twitter.com/products/tweetdeck', in_reply_to_status_id=None, in_reply_to_s ...
# ----------------------
# Status(_api=<tweepy.api.API object at 0x0000000012CFC5F8>, _json={'created_at': 'Sat Nov 02 23:02:33 +0000 2019', 'id': 1190766174356721664, 'id_str': '1190766174356721664', 'full_text': 'Wish an unholy alliance emerges between Shiv Sena, Congress and NCP ! Will pave way for BJP to come on top by wiping out such an opportunist grouping ! https://t.co/KTHZn34sdl', 'truncated': False, 'display_text_range': [0, 151], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/KTHZn34sdl', 'expanded_url': 'https://twitter.com/smitaprakash/status/1190460166942015488', 'display_url': 'twitter.com/smitaprakash/s…', 'indices': [152, 175]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 896846644993343488, 'id_str': '896846644993343488', 'name': 'L D Agarwal', 'screen_name': 'LDAgarwal1', 'location': 'West Bengal, India', 'description': 'Believe in strong, vibrant India as a Global Power in next ten years under the dynamic leadership of Narendra Modi !', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4517, 'friends_count': 4394, 'listed_count': 8, 'created_at': 'Sun Aug 13 21:31:17 +0000 2017', 'favourites_count': 80929, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count':
}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_st ...
# ----------------------

# %%
df = pd.DataFrame(columns = ['Tweets', 'User', 'User_statuses_count', 
                             'user_followers', 'User_location', 'User_verified',
                             'fav_count', 'rt_count', 'tweet_date'])

# %%
def stream(data, file_name):
    i = 0
    for tweet in tweepy.Cursor(api.search, q=data, count=100, lang='en').items():
        print(i, end='\r')
        df.loc[i, 'Tweets'] = tweet.text
        df.loc[i, 'User'] = tweet.user.name
        df.loc[i, 'User_statuses_count'] = tweet.user.statuses_count  # indicates the no. of times the user as tweeted 
        df.loc[i, 'user_followers'] = tweet.user.followers_count
        df.loc[i, 'User_location'] = tweet.user.location
        df.loc[i, 'User_verified'] = tweet.user.verified
        df.loc[i, 'fav_count'] = tweet.favorite_count
        df.loc[i, 'rt_count'] = tweet.retweet_count
        df.loc[i, 'tweet_date'] = tweet.created_at
        df.to_excel('{}.xlsx'.format(file_name))
        i+=1
        if i == 500:
            break
        else:
            pass

# %%
stream(data = ['BJP Shiv Sena Alliance'], file_name = 'myBJP_tweets')
# Out:
# 499

# %%
df.head()
# Out:
#                                               Tweets  \
# 0  Fate Of Maharashtra Assembly Elections  BJP Al...
# 1  RT @NATRAJSHETTY: The only solution for stable...
# 2  Fate Of Maharashtra Assembly Elections BJP All...
# 3  RT @Panipat_1761: Hello..Shiv Sena? Gentle rem...
# 4  RT @Panipat_1761: Hello..Shiv Sena? Gentle rem...
#
#                                            User User_statuses_count  \
# 0  Astrologer-astrodocanil-www.astrodocanil.com                1832
# 1                                 Rajendra Seth                 161
# 2  Astrologer-astrodocanil-www.astrodocanil.com                1832
# 3                        Haruko the Encouraging               75542
# 4                                suchittayashaH               39685
#
#   user_followers       User_location User_verified fav_count rt_count  \
# 0            194    New Delhi, India         False         0        0
# 1              1                             False         0        7
# 2            194    New Delhi, India         False         0        0
# 3            282  World of Slam Dunk         False         0        4
# 4           6330               India         False         0        4
#
#             tweet_date
# 0  2019-11-03 05:04:33
# 1  2019-11-03 05:03:53
# 2  2019-11-03 05:03:28
# 3  2019-11-03 04:58:04
# 4  2019-11-03 04:57:18

# %%
from textblob import TextBlob

# %%
import re
def clean_tweet(tweet):
    return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', tweet).split())

# %%
def analyze_sentiment(tweet):
    analysis = TextBlob(tweet)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity ==0:
        return 'Neutral'
    else:
        return 'Negative'

# %%
df['clean_tweet'] = df['Tweets'].apply(lambda x: clean_tweet(x))
df['Sentiment'] = df['clean_tweet'].apply(lambda x: analyze_sentiment(x))

# %%
n=300
print('Original tweet:\n'+ df['Tweets'][n])
print()
print('Clean tweet:\n'+df['clean_tweet'][n])
print()
print('Sentiment:\n'+df['Sentiment'][n])
# Out:
# Original tweet:
# RT @sri9011: BJP  made a  huge mistake by trusting Shiv Sena and fighting state elections in alliance.
#
# BJP should have gone it alone as th…
#
# Clean tweet:
# RT BJP made a huge mistake by trusting Shiv Sena and fighting state elections in alliance BJP should have gone it alone as th
#
# Sentiment:
# Positive

# %%
df[df.Sentiment == 'Positive'].shape[0]
# Out:
# 221

# %%
df[df.Sentiment == 'Negative'].shape[0]
# Out:
# 67

# %%
df[df.Sentiment == 'Neutral'].shape[0]
# Out:
# 212
